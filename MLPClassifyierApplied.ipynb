# %% [markdown]
# <a href="https://colab.research.google.com/github/smzain188/Machine_Learning_Projects/blob/main/MLPClassifyierApplied.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as nm
import pandas as pd

# %%
dt = pd.read_csv("/content/drive/MyDrive/Copy of Dataset-05.csv")
#DataSet Drive Link = https://drive.google.com/file/d/1xxNKhpjL4M33hOIuu1rqrVNtzykGuGpT/view?usp=sharing

# %%
dt.shape
dt
# Out:
#       sex  Age  Married  Number_children  education_level  total_members  \
# 0       1   28        1                4               10              5
# 1       1   23        1                3                8              5
# 2       1   22        1                3                9              5
# 3       1   27        1                2               10              4
# 4       0   59        0                4               10              6
# ...   ...  ...      ...              ...              ...            ...
# 1424    1   25        1                1                7              5
# 1425    1   28        1                4               10              6
# 1426    1   66        0                0                1              1
# 1427    1   51        1                1               12              5
# 1428    1   33        0                4                8              5
#
#       gained_asset  durable_asset  save_asset  living_expenses  \
# ...

# %%
x=dt.iloc[:,:-1]
y=dt.iloc[:,19]
x
# Out:
#       sex  Age  Married  Number_children  education_level  total_members  \
# 0       1   28        1                4               10              5
# 1       1   23        1                3                8              5
# 2       1   22        1                3                9              5
# 3       1   27        1                2               10              4
# 4       0   59        0                4               10              6
# ...   ...  ...      ...              ...              ...            ...
# 1424    1   25        1                1                7              5
# 1425    1   28        1                4               10              6
# 1426    1   66        0                0                1              1
# 1427    1   51        1                1               12              5
# 1428    1   33        0                4                8              5
#
#       gained_asset  durable_asset  save_asset  living_expenses  \
# ...

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=0)
xtrain
# Out:
#       sex  Age  Married  Number_children  education_level  total_members  \
# 1352    1   42        0                5                3              5
# 1325    1   76        1                0                1              2
# 299     1   30        1                2                9              4
# 420     1   26        1                4                8              5
# 513     1   36        1                4               14              6
# ...   ...  ...      ...              ...              ...            ...
# 763     1   30        1                0                9              2
# 835     1   21        1                2               14              5
# 1216    1   48        1                4                9              5
# 559     1   40        1                6                7              9
# 684     1   30        1                4               10              6
#
#       gained_asset  durable_asset  save_asset  living_expenses  \
# ...

# %% [markdown]
# #Standardrizer

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
xtrain=scale.fit_transform(xtrain)
xtest=scale.transform(xtest)

# %% [markdown]
# #Normalizer

# %%
# from sklearn.preprocessing import Normalizer
# scale = Normalizer()
# xtrain=scale.fit_transform(xtrain)
# xtest=scale.transform(xtest)

# %%
beforeSmote=ytrain
beforeSmote.value_counts()
# Out:
# 0    950
# 1    193
# Name: Class, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
smt=SMOTE(sampling_strategy="minority", random_state=0)
xtrain,ytrain=smt.fit_resample(xtrain,ytrain)

from imblearn.under_sampling import RandomUnderSampler 
rus = RandomUnderSampler(random_state=0)
xtrain,ytrain=rus.fit_resample(xtrain,ytrain)
ytrain.value_counts()
# Out:
# 0    950
# 1    950
# Name: Class, dtype: int64

# %%
ytrain.value_counts()
# Out:
# 0    950
# 1    950
# Name: Class, dtype: int64

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(random_state=0)
mlp.fit(xtrain, ytrain)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# MLPClassifier(random_state=0)

# %%
ypredictmlp=mlp.predict(xtest)

# %%
from sklearn.metrics import accuracy_score
accrf=accuracy_score(ytest,ypredictmlp)
accrf
# Out:
# 0.7202797202797203

# %%
from sklearn.metrics import confusion_matrix
mlpConfusionMatrix=confusion_matrix(ytest,ypredictmlp)
mlpConfusionMatrix
# Out:
# array([[188,  53],
#        [ 27,  18]])

# %%
from sklearn.metrics import classification_report
target_names = ['class 0', 'class 1']
print(classification_report(ytest, ypredictmlp, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.87      0.78      0.82       241
#      class 1       0.25      0.40      0.31        45
#
#     accuracy                           0.72       286
#    macro avg       0.56      0.59      0.57       286
# weighted avg       0.78      0.72      0.74       286
